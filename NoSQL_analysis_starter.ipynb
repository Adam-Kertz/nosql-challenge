# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
establishments.find_one()
# Out:
# {'_id': ObjectId('647a1e6bf8b6e796e1a6027a'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5.0,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %%
# Find the establishments with a hygiene score of 20
hygiene_query = {'scores.Hygiene': 20}
hygiene_results = establishments.find(hygiene_query)

# Use count_documents to display the number of documents in the result
print(f"There are {establishments.count_documents(hygiene_query)} establishments with a hygiene score of 20.\n")

# Display the first document in the results using pprint
print("Here is an example:")
pprint(hygiene_results[0])
# Out:
# There are 41 establishments with a hygiene score of 20.
#
# Here is an example:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0.0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('647a1e6bf8b6e796e1a61dac'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
for result in hygiene_results:
    print(result['AddressLine1'])
    print(result['AddressLine2'])
    print(result['AddressLine3'])
    print(result['AddressLine4'])
# Out:
# 5-6 Southfields Road
# Eastbourne
# East Sussex
#
# Hall Lane
# Walton-on-the-Naze
# Essex
#
# 53 Marine Parade East
# Clacton On Sea
# Essex
#
# 4 High Street
# Seaford
# East Sussex
#
# 5 South Street
# Seaford
# East Sussex
#
# 777 Southchurch Road
# Southend-On-Sea
# Essex
#
# 33 Alexandra Street
# Southend-on-sea
# Essex
#
# 7 London Road
# Rayleigh
# Essex
#
# 3 The Village
# Chiddingstone
# KENT
#
#
# 81 Southernhay
# Basildon
# Essex
# 17 London Road
# Riverhead
# KENT
#
# Downsview Community Primary School
# Beech Avenue
# Swanley
# KENT
# EMR Erith
# Manor Road
# Erith
# Kent
# 43 Kings Road
# Brentwood
# Essex
#
# 24 Station Lane
# Hornchurch
#
#
# 2 - 6 Basildon Road
#
# Abbey Wood
# Greenwich
# 5 - 7 Cranley Parade
# Beaconsfield Road
# Mottingham
# London
# 2 The Slade
#
# Plumstead
# Greenwich
#
# 8 Porters Avenue
#
# Dagenham
#
# 87 Longbridge Road
#
# Barking
#
# 66 Station Parade
#
# Barking
# 5 High Street South
# East Ham
# London
#
#
# 221 Ilford Lane
#
# Ilford
#
# 108 Ilford Lane
#
# Ilford
#
# 149 Ley Street
#
# Ilford
# 151 - 153 Barking Road
# East Ham
# London
#
# 221 High Street North
# East Ham
# London
#
# 241B High Street North
# Manor Park
# London
#
# 333 Barking Road
# Plaistow
# London
#
# 282 Barking Road
# Plaistow
# London
#
# 369 Katherine Road
# Forest Gate
# London
#
# The Kinema
# Chelmsford Road
# Dunmow
#
# 76 Green Street
# Forest Gate
# London
#
# 23 Stortford Road
# Dunmow
#
#
# 34 West Ham Lane
# Stratford
# London
#
#
# 345 High Road Leytonstone
#
# Leytonstone
#
# 32 Church Lane
#
# Leytonstone
#
# 14 Hatch Lane
#
# Chingford
# Great Hallingbury Manor
# Tilekiln Green
# Great Hallingbury
# Bishops Stortford
# 58 Lower Street
# Stansted
# Essex
#
# 1 Mercers Row
# Saffron Walden
# Essex

# %%
# Convert the result to a Pandas DataFrame
hygiene_results = establishments.find(hygiene_query)
hygiene_df = pd.DataFrame(hygiene_results).set_index('_id',drop=True)

# Display the number of rows in the DataFrame
print(f"There are {hygiene_df.shape[0]} rows in the DataFrame.")

# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
# There are 41 rows in the DataFrame.
#                            FHRSID  ChangesByServerID LocalAuthorityBusinessID  \
# _id
# 647a1e6bf8b6e796e1a61dac   110681                  0                     4029
# 647a1e6bf8b6e796e1a62134   612039                  0                1970/FOOD
# 647a1e6bf8b6e796e1a62439   730933                  0                1698/FOOD
# 647a1e6bf8b6e796e1a62626   172735                  0             PI/000023858
# 647a1e6bf8b6e796e1a62636   172953                  0             PI/000024532
# 647a1e6bf8b6e796e1a62fd6   512854                  0            12/00816/BUTH
# 647a1e6bf8b6e796e1a631f5  1537089                  0          22/00224/RESTUN
# 647a1e6bf8b6e796e1a64723   155648                  0              EH/00006058
# 647a1e6bf8b6e796e1a64b65  1012883                  0         17/00110/MIXED/S
# 647a1e6cf8b6e796e1a65378   644109                  0                    41811
#
#                                        BusinessName  \
# _id
# 647a1e6bf8b6e796e1a61dac        The Chase Rest Home
# 647a1e6bf8b6e796e1a62134                 Brenalwood
# 647a1e6bf8b6e796e1a62439              Melrose Hotel
# 647a1e6bf8b6e796e1a62626              Seaford Pizza
# 647a1e6bf8b6e796e1a62636              Golden Palace
# 647a1e6bf8b6e796e1a62fd6           Ashby's Butchers
# 647a1e6bf8b6e796e1a631f5  South Sea Express Cuisine
# 647a1e6bf8b6e796e1a64723              Golden Palace
# 647a1e6bf8b6e796e1a64b65             The Tulip Tree
# 647a1e6cf8b6e796e1a65378                      F & S
#
#                                                BusinessType  BusinessTypeID  \
# _id
# 647a1e6bf8b6e796e1a61dac                    Caring Premises               5
# 647a1e6bf8b6e796e1a62134                    Caring Premises               5
# 647a1e6bf8b6e796e1a62439  Hotel/bed & breakfast/guest house            7842
# 647a1e6bf8b6e796e1a62626             Takeaway/sandwich shop            7844
# 647a1e6bf8b6e796e1a62636            Restaurant/Cafe/Canteen               1
# 647a1e6bf8b6e796e1a62fd6                  Retailers - other            4613
# 647a1e6bf8b6e796e1a631f5            Restaurant/Cafe/Canteen               1
# 647a1e6bf8b6e796e1a64723             Takeaway/sandwich shop            7844
# 647a1e6bf8b6e796e1a64b65            Restaurant/Cafe/Canteen               1
# 647a1e6cf8b6e796e1a65378                  Retailers - other            4613
#
#                                    AddressLine1        AddressLine2  \
# _id
# 647a1e6bf8b6e796e1a61dac   5-6 Southfields Road          Eastbourne
# 647a1e6bf8b6e796e1a62134              Hall Lane  Walton-on-the-Naze
# 647a1e6bf8b6e796e1a62439  53 Marine Parade East      Clacton On Sea
# 647a1e6bf8b6e796e1a62626          4 High Street             Seaford
# 647a1e6bf8b6e796e1a62636         5 South Street             Seaford
# 647a1e6bf8b6e796e1a62fd6   777 Southchurch Road     Southend-On-Sea
# 647a1e6bf8b6e796e1a631f5    33 Alexandra Street     Southend-on-sea
# 647a1e6bf8b6e796e1a64723          7 London Road            Rayleigh
# 647a1e6bf8b6e796e1a64b65          3 The Village       Chiddingstone
# 647a1e6cf8b6e796e1a65378                             81 Southernhay
#
#                          AddressLine3 AddressLine4  ...  \
# _id                                                 ...
# 647a1e6bf8b6e796e1a61dac  East Sussex               ...
# 647a1e6bf8b6e796e1a62134        Essex               ...
# 647a1e6bf8b6e796e1a62439        Essex               ...
# 647a1e6bf8b6e796e1a62626  East Sussex               ...
# 647a1e6bf8b6e796e1a62636  East Sussex               ...
# 647a1e6bf8b6e796e1a62fd6        Essex               ...
# 647a1e6bf8b6e796e1a631f5        Essex               ...
# 647a1e6bf8b6e796e1a64723        Essex               ...
# 647a1e6bf8b6e796e1a64b65         KENT               ...
# 647a1e6cf8b6e796e1a65378     Basildon        Essex  ...
#
#                                              LocalAuthorityWebSite  \
# _id
# 647a1e6bf8b6e796e1a61dac  http://www.eastbourne.gov.uk/foodratings
# 647a1e6bf8b6e796e1a62134             http://www.tendringdc.gov.uk/
# 647a1e6bf8b6e796e1a62439             http://www.tendringdc.gov.uk/
# 647a1e6bf8b6e796e1a62626       http://www.lewes-eastbourne.gov.uk/
# 647a1e6bf8b6e796e1a62636       http://www.lewes-eastbourne.gov.uk/
# 647a1e6bf8b6e796e1a62fd6                http://www.southend.gov.uk
# 647a1e6bf8b6e796e1a631f5                http://www.southend.gov.uk
# 647a1e6bf8b6e796e1a64723                http://www.rochford.gov.uk
# 647a1e6bf8b6e796e1a64b65              http://www.sevenoaks.gov.uk/
# 647a1e6cf8b6e796e1a65378                http://www.basildon.gov.uk
#
#                                      LocalAuthorityEmailAddress  \
# _id
# 647a1e6bf8b6e796e1a61dac        Customerfirst@eastbourne.gov.uk
# 647a1e6bf8b6e796e1a62134             fhsadmin@tendringdc.gov.uk
# 647a1e6bf8b6e796e1a62439             fhsadmin@tendringdc.gov.uk
# 647a1e6bf8b6e796e1a62626    ehealth.ldc@lewes-eastbourne.gov.uk
# 647a1e6bf8b6e796e1a62636    ehealth.ldc@lewes-eastbourne.gov.uk
# 647a1e6bf8b6e796e1a62fd6    EnvironmentalHealth@southend.gov.uk
# 647a1e6bf8b6e796e1a631f5    EnvironmentalHealth@southend.gov.uk
# 647a1e6bf8b6e796e1a64723       customerservices@rochford.gov.uk
# 647a1e6bf8b6e796e1a64b65  environmental.health@sevenoaks.gov.uk
# 647a1e6cf8b6e796e1a65378                    ehs@basildon.gov.uk
#
#                                                                      scores  \
# _id
# 647a1e6bf8b6e796e1a61dac  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 647a1e6bf8b6e796e1a62134  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 647a1e6bf8b6e796e1a62439  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 647a1e6bf8b6e796e1a62626  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# 647a1e6bf8b6e796e1a62636  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# 647a1e6bf8b6e796e1a62fd6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 647a1e6bf8b6e796e1a631f5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 647a1e6bf8b6e796e1a64723  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 647a1e6bf8b6e796e1a64b65  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...
# 647a1e6cf8b6e796e1a65378  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
#
#                          SchemeType  \
# _id
# 647a1e6bf8b6e796e1a61dac       FHRS
# 647a1e6bf8b6e796e1a62134       FHRS
# 647a1e6bf8b6e796e1a62439       FHRS
# 647a1e6bf8b6e796e1a62626       FHRS
# 647a1e6bf8b6e796e1a62636       FHRS
# 647a1e6bf8b6e796e1a62fd6       FHRS
# 647a1e6bf8b6e796e1a631f5       FHRS
# 647a1e6bf8b6e796e1a64723       FHRS
# 647a1e6bf8b6e796e1a64b65       FHRS
# 647a1e6cf8b6e796e1a65378       FHRS
#
#                                                                     geocode  \
# _id
# 647a1e6bf8b6e796e1a61dac      {'longitude': 0.27694, 'latitude': 50.769705}
# 647a1e6bf8b6e796e1a62134     {'longitude': 1.278721, 'latitude': 51.857536}
# 647a1e6bf8b6e796e1a62439      {'longitude': 1.15927, 'latitude': 51.789429}
# 647a1e6bf8b6e796e1a62626      {'longitude': 0.10202, 'latitude': 50.770885}
# 647a1e6bf8b6e796e1a62636     {'longitude': 0.101446, 'latitude': 50.770724}
# 647a1e6bf8b6e796e1a62fd6     {'longitude': 0.736349, 'latitude': 51.541448}
# 647a1e6bf8b6e796e1a631f5   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 647a1e6bf8b6e796e1a64723     {'longitude': 0.602364, 'latitude': 51.591515}
# 647a1e6bf8b6e796e1a64b65  {'longitude': 0.146449998021126, 'latitude': 5...
# 647a1e6cf8b6e796e1a65378      {'longitude': 0.462307, 'latitude': 51.57005}
#
#                          RightToReply     Distance NewRatingPending  \
# _id
# 647a1e6bf8b6e796e1a61dac               4613.888288            False
# 647a1e6bf8b6e796e1a62134               4617.965824            False
# 647a1e6bf8b6e796e1a62439               4619.656144            False
# 647a1e6bf8b6e796e1a62626               4620.421725            False
# 647a1e6bf8b6e796e1a62636               4620.437179            False
# 647a1e6bf8b6e796e1a62fd6               4625.565258            False
# 647a1e6bf8b6e796e1a631f5               4626.200132            False
# 647a1e6bf8b6e796e1a64723               4632.276890            False
# 647a1e6bf8b6e796e1a64b65               4633.934041            False
# 647a1e6cf8b6e796e1a65378               4636.552523            False
#
#                                                                        meta  \
# _id
# 647a1e6bf8b6e796e1a61dac  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6bf8b6e796e1a62134  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6bf8b6e796e1a62439  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6bf8b6e796e1a62626  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6bf8b6e796e1a62636  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6bf8b6e796e1a62fd6  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6bf8b6e796e1a631f5  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6bf8b6e796e1a64723  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6bf8b6e796e1a64b65  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6cf8b6e796e1a65378  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                                       links
# _id
# 647a1e6bf8b6e796e1a61dac  [{'rel': 'self', 'href': 'https://api.ratings....
# 647a1e6bf8b6e796e1a62134  [{'rel': 'self', 'href': 'https://api.ratings....
# 647a1e6bf8b6e796e1a62439  [{'rel': 'self', 'href': 'https://api.ratings....
# 647a1e6bf8b6e796e1a62626  [{'rel': 'self', 'href': 'https://api.ratings....
# 647a1e6bf8b6e796e1a62636  [{'rel': 'self', 'href': 'https://api.ratings....
# 647a1e6bf8b6e796e1a62fd6  [{'rel': 'self', 'href': 'https://api.ratings....
# 647a1e6bf8b6e796e1a631f5  [{'rel': 'self', 'href': 'https://api.ratings....
# 647a1e6bf8b6e796e1a64723  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6bf8b6e796e1a64b65  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6cf8b6e796e1a65378  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 27 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
London_query = {'LocalAuthorityName':{'$regex':'London'}}
rating_query = {'$and':[London_query,{'RatingValue': {'$gte': 4}}]}
rating_results = establishments.find(rating_query)

# Use count_documents to display the number of documents in the result
print(f"There are {establishments.count_documents(rating_query)} London establishments with a rating greater than or equal to 4.\n")

# Display the first document in the results using pprint
print("Here is an example:")
# Out:
# There are 33 London establishments with a rating greater than or equal to 4.
#
# Here is an example:

# %%
# Convert the result to a Pandas DataFrame
rating_results = establishments.find(rating_query)
rating_df = pd.DataFrame(rating_results).set_index('_id',drop=True)

# Display the number of rows in the DataFrame
print(f"There are {rating_df.shape[0]} rows in the DataFrame.")

# Display the first 10 rows of the DataFrame
rating_df.head(10)
# Out:
# There are 33 rows in the DataFrame.
#                            FHRSID  ChangesByServerID LocalAuthorityBusinessID  \
# _id
# 647a1e6bf8b6e796e1a637ca   621707                  0             PI/000025307
# 647a1e6bf8b6e796e1a63af0  1130836                  0             PI/000034075
# 647a1e6bf8b6e796e1a6463d   293783                  0             PI/000002614
# 647a1e6cf8b6e796e1a6543d   294474                  0             PI/000014647
# 647a1e6cf8b6e796e1a6543e  1315095                  0             PI/000036464
# 647a1e6cf8b6e796e1a65b46   294900                  0             PI/000019066
# 647a1e6cf8b6e796e1a67c54   293756                  0             PI/000002538
# 647a1e6cf8b6e796e1a68019   878523                  0             PI/000029844
# 647a1e6cf8b6e796e1a68034   293772                  0             PI/000002585
# 647a1e6cf8b6e796e1a68035   294606                  0             PI/000016185
#
#                                                   BusinessName  \
# _id
# 647a1e6bf8b6e796e1a637ca                             Charlie's
# 647a1e6bf8b6e796e1a63af0               Mv City Cruises Erasmus
# 647a1e6bf8b6e796e1a6463d             Benfleet Motor Yacht Club
# 647a1e6cf8b6e796e1a6543d              Tilbury Seafarers Centre
# 647a1e6cf8b6e796e1a6543e  Coombs Catering t/a The Lock and Key
# 647a1e6cf8b6e796e1a65b46                            Mv Valulla
# 647a1e6cf8b6e796e1a67c54                         Tereza Joanne
# 647a1e6cf8b6e796e1a68019                      Brick Lane Brews
# 647a1e6cf8b6e796e1a68034         The Nuance Group (UK) Limited
# 647a1e6cf8b6e796e1a68035                              WH Smith
#
#                                      BusinessType  BusinessTypeID  \
# _id
# 647a1e6bf8b6e796e1a637ca  Other catering premises            7841
# 647a1e6bf8b6e796e1a63af0  Other catering premises            7841
# 647a1e6bf8b6e796e1a6463d  Other catering premises            7841
# 647a1e6cf8b6e796e1a6543d  Restaurant/Cafe/Canteen               1
# 647a1e6cf8b6e796e1a6543e  Restaurant/Cafe/Canteen               1
# 647a1e6cf8b6e796e1a65b46  Other catering premises            7841
# 647a1e6cf8b6e796e1a67c54  Other catering premises            7841
# 647a1e6cf8b6e796e1a68019  Restaurant/Cafe/Canteen               1
# 647a1e6cf8b6e796e1a68034        Retailers - other            4613
# 647a1e6cf8b6e796e1a68035        Retailers - other            4613
#
#                                                                AddressLine1  \
# _id
# 647a1e6bf8b6e796e1a637ca         Oak Apple Farm Building 103 Sheernes Docks
# 647a1e6bf8b6e796e1a63af0                                 Cherry Garden Pier
# 647a1e6bf8b6e796e1a6463d                                         Ferry Road
# 647a1e6cf8b6e796e1a6543d                          Tenants Row Tilbury Docks
# 647a1e6cf8b6e796e1a6543e                                  Leslie Ford House
# 647a1e6cf8b6e796e1a65b46  Reeds River Cruises LtdKings ReachRiver Thames...
# 647a1e6cf8b6e796e1a67c54  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 647a1e6cf8b6e796e1a68019                       Air side London City Airport
# 647a1e6cf8b6e796e1a68034                  Duty Free Shop Passenger Terminal
# 647a1e6cf8b6e796e1a68035                                London City Airport
#
#                                                   AddressLine2 AddressLine3  \
# _id
# 647a1e6bf8b6e796e1a637ca                           Sheppy Kent
# 647a1e6bf8b6e796e1a63af0      Cherry Garden Street Rotherhithe     Charlton
# 647a1e6bf8b6e796e1a6463d                  South Benfleet Essex
# 647a1e6cf8b6e796e1a6543d                         Tilbury Essex
# 647a1e6cf8b6e796e1a6543e                               Tilbury     Charlton
# 647a1e6cf8b6e796e1a65b46                                London
# 647a1e6cf8b6e796e1a67c54                                London
# 647a1e6cf8b6e796e1a68019                                London
# 647a1e6cf8b6e796e1a68034  London City AirportRoyal DocksLondon
# 647a1e6cf8b6e796e1a68035                     Silvertown London
#
#                          AddressLine4  ...  \
# _id                                    ...
# 647a1e6bf8b6e796e1a637ca               ...
# 647a1e6bf8b6e796e1a63af0               ...
# 647a1e6bf8b6e796e1a6463d               ...
# 647a1e6cf8b6e796e1a6543d               ...
# 647a1e6cf8b6e796e1a6543e               ...
# 647a1e6cf8b6e796e1a65b46               ...
# 647a1e6cf8b6e796e1a67c54               ...
# 647a1e6cf8b6e796e1a68019               ...
# 647a1e6cf8b6e796e1a68034               ...
# 647a1e6cf8b6e796e1a68035               ...
#
#                                                       LocalAuthorityWebSite  \
# _id
# 647a1e6bf8b6e796e1a637ca  http://www.cityoflondon.gov.uk/Corporation/hom...
# 647a1e6bf8b6e796e1a63af0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 647a1e6bf8b6e796e1a6463d  http://www.cityoflondon.gov.uk/Corporation/hom...
# 647a1e6cf8b6e796e1a6543d  http://www.cityoflondon.gov.uk/Corporation/hom...
# 647a1e6cf8b6e796e1a6543e  http://www.cityoflondon.gov.uk/Corporation/hom...
# 647a1e6cf8b6e796e1a65b46  http://www.cityoflondon.gov.uk/Corporation/hom...
# 647a1e6cf8b6e796e1a67c54  http://www.cityoflondon.gov.uk/Corporation/hom...
# 647a1e6cf8b6e796e1a68019  http://www.cityoflondon.gov.uk/Corporation/hom...
# 647a1e6cf8b6e796e1a68034  http://www.cityoflondon.gov.uk/Corporation/hom...
# 647a1e6cf8b6e796e1a68035  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#                                     LocalAuthorityEmailAddress  \
# _id
# 647a1e6bf8b6e796e1a637ca  publicprotection@cityoflondon.gov.uk
# 647a1e6bf8b6e796e1a63af0  publicprotection@cityoflondon.gov.uk
# 647a1e6bf8b6e796e1a6463d  publicprotection@cityoflondon.gov.uk
# 647a1e6cf8b6e796e1a6543d  publicprotection@cityoflondon.gov.uk
# 647a1e6cf8b6e796e1a6543e  publicprotection@cityoflondon.gov.uk
# 647a1e6cf8b6e796e1a65b46  publicprotection@cityoflondon.gov.uk
# 647a1e6cf8b6e796e1a67c54  publicprotection@cityoflondon.gov.uk
# 647a1e6cf8b6e796e1a68019  publicprotection@cityoflondon.gov.uk
# 647a1e6cf8b6e796e1a68034  publicprotection@cityoflondon.gov.uk
# 647a1e6cf8b6e796e1a68035  publicprotection@cityoflondon.gov.uk
#
#                                                                      scores  \
# _id
# 647a1e6bf8b6e796e1a637ca  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...
# 647a1e6bf8b6e796e1a63af0  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# 647a1e6bf8b6e796e1a6463d  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# 647a1e6cf8b6e796e1a6543d  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# 647a1e6cf8b6e796e1a6543e  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# 647a1e6cf8b6e796e1a65b46  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# 647a1e6cf8b6e796e1a67c54  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# 647a1e6cf8b6e796e1a68019  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...
# 647a1e6cf8b6e796e1a68034  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# 647a1e6cf8b6e796e1a68035  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
#
#                          SchemeType  \
# _id
# 647a1e6bf8b6e796e1a637ca       FHRS
# 647a1e6bf8b6e796e1a63af0       FHRS
# 647a1e6bf8b6e796e1a6463d       FHRS
# 647a1e6cf8b6e796e1a6543d       FHRS
# 647a1e6cf8b6e796e1a6543e       FHRS
# 647a1e6cf8b6e796e1a65b46       FHRS
# 647a1e6cf8b6e796e1a67c54       FHRS
# 647a1e6cf8b6e796e1a68019       FHRS
# 647a1e6cf8b6e796e1a68034       FHRS
# 647a1e6cf8b6e796e1a68035       FHRS
#
#                                                                     geocode  \
# _id
# 647a1e6bf8b6e796e1a637ca     {'longitude': 0.508551, 'latitude': 51.369321}
# 647a1e6bf8b6e796e1a63af0  {'longitude': 0.249255999922752, 'latitude': 5...
# 647a1e6bf8b6e796e1a6463d     {'longitude': 0.561954, 'latitude': 51.543831}
# 647a1e6cf8b6e796e1a6543d     {'longitude': 0.346325, 'latitude': 51.464078}
# 647a1e6cf8b6e796e1a6543e  {'longitude': 0.346336990594864, 'latitude': 5...
# 647a1e6cf8b6e796e1a65b46     {'longitude': 0.287555, 'latitude': 51.504071}
# 647a1e6cf8b6e796e1a67c54     {'longitude': 0.069286, 'latitude': 51.501121}
# 647a1e6cf8b6e796e1a68019     {'longitude': 0.048006, 'latitude': 51.503733}
# 647a1e6cf8b6e796e1a68034     {'longitude': 0.047966, 'latitude': 51.504112}
# 647a1e6cf8b6e796e1a68035  {'longitude': 0.0479655750095844, 'latitude': ...
#
#                          RightToReply     Distance NewRatingPending  \
# _id
# 647a1e6bf8b6e796e1a637ca               4627.439468            False
# 647a1e6bf8b6e796e1a63af0               4627.873179            False
# 647a1e6bf8b6e796e1a6463d               4631.968418            False
# 647a1e6cf8b6e796e1a6543d               4636.847650            False
# 647a1e6cf8b6e796e1a6543e               4636.846754            False
# 647a1e6cf8b6e796e1a65b46               4640.460834            False
# 647a1e6cf8b6e796e1a67c54               4648.301822            False
# 647a1e6cf8b6e796e1a68019               4649.173485            False
# 647a1e6cf8b6e796e1a68034               4649.188826            False
# 647a1e6cf8b6e796e1a68035               4649.188850            False
#
#                                                                        meta  \
# _id
# 647a1e6bf8b6e796e1a637ca  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6bf8b6e796e1a63af0  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6bf8b6e796e1a6463d  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6cf8b6e796e1a6543d  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6cf8b6e796e1a6543e  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6cf8b6e796e1a65b46  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6cf8b6e796e1a67c54  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6cf8b6e796e1a68019  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6cf8b6e796e1a68034  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6cf8b6e796e1a68035  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                                       links
# _id
# 647a1e6bf8b6e796e1a637ca  [{'rel': 'self', 'href': 'https://api.ratings....
# 647a1e6bf8b6e796e1a63af0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6bf8b6e796e1a6463d  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6cf8b6e796e1a6543d  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6cf8b6e796e1a6543e  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6cf8b6e796e1a65b46  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6cf8b6e796e1a67c54  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6cf8b6e796e1a68019  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6cf8b6e796e1a68034  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6cf8b6e796e1a68035  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 27 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

# Define degree of variance
degree_search = 0.01

# Get information on Penang Flavours Establishment
new_business_query = {"BusinessName":"Penang Flavours"}
new_business_results = establishments.find_one(new_business_query)

# Obtain latitude and longitude from query
latitude = new_business_results.get('geocode').get('latitude')
longitude = new_business_results.get('geocode').get('longitude')

# Define latitude and longitude limits for new query
lat_min = latitude - degree_search
lat_max = latitude + degree_search
lon_min = longitude - degree_search
lon_max = longitude + degree_search

# Define query and sort criteria for restaurants in desired range
distance_query = {'$and':[{'geocode.latitude':{'$gte': lat_min}},{'geocode.latitude':{'$lte':lat_max}}
                 ,{'geocode.longitude':{'$gte':lon_min}},{'geocode.longitude':{'$lte':lon_max}}]}
distance_sort = [('scores.Hygiene', 1)]

# Find establishments of note
distance_results = establishments.find(distance_query).sort(distance_sort).limit(5)

# Print the results
for result in distance_results:
    pprint(result)
# Out:
# {'AddressLine1': '109 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Euro express',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4646.996158638568,
#  'FHRSID': 1538211,
#  'LocalAuthorityBusinessID': '15382',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SE',
#  'RatingDate': '1901-01-01T00:00:00',
#  'RatingKey': 'fhrs_awaitinginspection_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('647a1e6cf8b6e796e1a6767b'),
#  'geocode': {'latitude': 51.4877206, 'longitude': 0.0916219},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1538211',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Supreme Education',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4646.9740101340385,
#  'FHRSID': 1489058,
#  'LocalAuthorityBusinessID': '15076',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1QG',
#  'RatingDate': '1901-01-01T00:00:00',
#  'RatingKey': 'fhrs_awaitinginspection_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('647a1e6cf8b6e796e1a67635'),
#  'geocode': {'latitude': 51.481517791748, 'longitude': 0.0859939977526665},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1489058',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': '44 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Plumstead suya spot',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4647.15912417714,
#  'FHRSID': 1538214,
#  'LocalAuthorityBusinessID': '15385',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1SL',
#  'RatingDate': '1901-01-01T00:00:00',
#  'RatingKey': 'fhrs_awaitinginspection_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('647a1e6cf8b6e796e1a677a6'),
#  'geocode': {'latitude': 51.4885601, 'longitude': 0.087997},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1538214',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': 'The Old Mill 1 Old Mill Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Crab and Crayfish',
#  'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  'ChangesByServerID': 0,
#  'Distance': 4647.050320500107,
#  'FHRSID': 1516619,
#  'LocalAuthorityBusinessID': '15218',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1QG',
#  'RatingDate': '1901-01-01T00:00:00',
#  'RatingKey': 'fhrs_awaitinginspection_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('647a1e6cf8b6e796e1a676dd'),
#  'geocode': {'latitude': 51.4817109, 'longitude': 0.0840959},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1516619',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': '49 Lakedale Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Kingsmeat Smokehouse',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4646.958610147575,
#  'FHRSID': 1489059,
#  'LocalAuthorityBusinessID': '15077',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1PR',
#  'RatingDate': '1901-01-01T00:00:00',
#  'RatingKey': 'fhrs_awaitinginspection_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('647a1e6cf8b6e796e1a67609'),
#  'geocode': {'latitude': 51.4863774, 'longitude': 0.0913011},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1489059',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}

# %%
# Convert result to Pandas DataFrame
distance_results = establishments.find(distance_query).sort(distance_sort).limit(5)
distance_df = pd.DataFrame(distance_results).set_index('_id',drop=True)
distance_df.head()
# Out:
#                            FHRSID  ChangesByServerID LocalAuthorityBusinessID  \
# _id
# 647a1e6cf8b6e796e1a6767b  1538211                  0                    15382
# 647a1e6cf8b6e796e1a67635  1489058                  0                    15076
# 647a1e6cf8b6e796e1a677a6  1538214                  0                    15385
# 647a1e6cf8b6e796e1a676dd  1516619                  0                    15218
# 647a1e6cf8b6e796e1a67609  1489059                  0                    15077
#
#                                   BusinessName             BusinessType  \
# _id
# 647a1e6cf8b6e796e1a6767b          Euro express        Retailers - other
# 647a1e6cf8b6e796e1a67635     Supreme Education          Caring Premises
# 647a1e6cf8b6e796e1a677a6   Plumstead suya spot   Takeaway/sandwich shop
# 647a1e6cf8b6e796e1a676dd     Crab and Crayfish           Mobile caterer
# 647a1e6cf8b6e796e1a67609  Kingsmeat Smokehouse  Other catering premises
#
#                           BusinessTypeID  \
# _id
# 647a1e6cf8b6e796e1a6767b            4613
# 647a1e6cf8b6e796e1a67635               5
# 647a1e6cf8b6e796e1a677a6            7844
# 647a1e6cf8b6e796e1a676dd            7846
# 647a1e6cf8b6e796e1a67609            7841
#
#                                                   AddressLine1 AddressLine2  \
# _id
# 647a1e6cf8b6e796e1a6767b             109 Plumstead High Street
# 647a1e6cf8b6e796e1a67635  Plumstead Manor School Old Mill Road
# 647a1e6cf8b6e796e1a677a6              44 Plumstead High Street
# 647a1e6cf8b6e796e1a676dd          The Old Mill 1 Old Mill Road
# 647a1e6cf8b6e796e1a67609                      49 Lakedale Road
#
#                          AddressLine3 AddressLine4  ...  \
# _id                                                 ...
# 647a1e6cf8b6e796e1a6767b    Plumstead    Greenwich  ...
# 647a1e6cf8b6e796e1a67635    Plumstead    Greenwich  ...
# 647a1e6cf8b6e796e1a677a6    Plumstead    Greenwich  ...
# 647a1e6cf8b6e796e1a676dd    Plumstead    Greenwich  ...
# 647a1e6cf8b6e796e1a67609    Plumstead    Greenwich  ...
#
#                                      LocalAuthorityWebSite  \
# _id
# 647a1e6cf8b6e796e1a6767b  http://www.royalgreenwich.gov.uk
# 647a1e6cf8b6e796e1a67635  http://www.royalgreenwich.gov.uk
# 647a1e6cf8b6e796e1a677a6  http://www.royalgreenwich.gov.uk
# 647a1e6cf8b6e796e1a676dd  http://www.royalgreenwich.gov.uk
# 647a1e6cf8b6e796e1a67609  http://www.royalgreenwich.gov.uk
#
#                             LocalAuthorityEmailAddress  \
# _id
# 647a1e6cf8b6e796e1a6767b  health@royalgreenwich.gov.uk
# 647a1e6cf8b6e796e1a67635  health@royalgreenwich.gov.uk
# 647a1e6cf8b6e796e1a677a6  health@royalgreenwich.gov.uk
# 647a1e6cf8b6e796e1a676dd  health@royalgreenwich.gov.uk
# 647a1e6cf8b6e796e1a67609  health@royalgreenwich.gov.uk
#
#                                                                      scores  \
# _id
# 647a1e6cf8b6e796e1a6767b  {'Hygiene': None, 'Structural': None, 'Confide...
# 647a1e6cf8b6e796e1a67635  {'Hygiene': None, 'Structural': None, 'Confide...
# 647a1e6cf8b6e796e1a677a6  {'Hygiene': None, 'Structural': None, 'Confide...
# 647a1e6cf8b6e796e1a676dd  {'Hygiene': None, 'Structural': None, 'Confide...
# 647a1e6cf8b6e796e1a67609  {'Hygiene': None, 'Structural': None, 'Confide...
#
#                          SchemeType  \
# _id
# 647a1e6cf8b6e796e1a6767b       FHRS
# 647a1e6cf8b6e796e1a67635       FHRS
# 647a1e6cf8b6e796e1a677a6       FHRS
# 647a1e6cf8b6e796e1a676dd       FHRS
# 647a1e6cf8b6e796e1a67609       FHRS
#
#                                                                     geocode  \
# _id
# 647a1e6cf8b6e796e1a6767b   {'longitude': 0.0916219, 'latitude': 51.4877206}
# 647a1e6cf8b6e796e1a67635  {'longitude': 0.0859939977526665, 'latitude': ...
# 647a1e6cf8b6e796e1a677a6    {'longitude': 0.087997, 'latitude': 51.4885601}
# 647a1e6cf8b6e796e1a676dd   {'longitude': 0.0840959, 'latitude': 51.4817109}
# 647a1e6cf8b6e796e1a67609   {'longitude': 0.0913011, 'latitude': 51.4863774}
#
#                          RightToReply     Distance NewRatingPending  \
# _id
# 647a1e6cf8b6e796e1a6767b               4646.996159            False
# 647a1e6cf8b6e796e1a67635               4646.974010            False
# 647a1e6cf8b6e796e1a677a6               4647.159124            False
# 647a1e6cf8b6e796e1a676dd               4647.050321            False
# 647a1e6cf8b6e796e1a67609               4646.958610            False
#
#                                                                        meta  \
# _id
# 647a1e6cf8b6e796e1a6767b  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6cf8b6e796e1a67635  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6cf8b6e796e1a677a6  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6cf8b6e796e1a676dd  {'dataSource': None, 'extractDate': '0001-01-0...
# 647a1e6cf8b6e796e1a67609  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                                       links
# _id
# 647a1e6cf8b6e796e1a6767b  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6cf8b6e796e1a67635  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6cf8b6e796e1a677a6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6cf8b6e796e1a676dd  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 647a1e6cf8b6e796e1a67609  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
pipeline_query = {'scores.Hygiene': 0} 
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline_sort = [('LocalAuthorityBusinessID',-1)]

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
